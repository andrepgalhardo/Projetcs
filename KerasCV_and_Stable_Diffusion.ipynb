# %% [markdown]
# <a href="https://colab.research.google.com/github/andrepgalhardo/Projects/blob/main/KerasCV_and_Stable_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import keras_cv
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend

# %%
model = keras_cv.models.StableDiffusion(img_height=512, img_width=512)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
images = model.text_to_image('A supercomputer with an extraterrestrial human-android operating it.', batch_size=3)

def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")

plot_images(images)
# Out:
# 50/50 [==============================] - 94s 2s/step

# %%
images = model.text_to_image('A father and son in a simple house in an oil painting.', batch_size=3)

def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")

plot_images(images)
# Out:
# 50/50 [==============================] - 93s 2s/step
